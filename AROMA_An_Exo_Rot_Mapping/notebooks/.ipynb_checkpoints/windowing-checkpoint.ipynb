# %% [markdown]
# # WINDOW FUNCTION: TESS vs LIGHT CURVE
# ## LIGHT CURVE
#
# ## TESS
#
# #### Note on path and package import
# Before importing user-defined package (`AROMA` in this case), you might want to `pip install <path/to/AROMA>` where `<path/to/AROMA>` is the folder containing `setup.py`.

# %%
from AROMA import *
from AROMA.utils import *
from AROMA.config import *
import pandas as pd
# %matplotlib widget

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
print('def: find_nearest(array, value)')

import os
from os.path import join
array = os.path.abspath('').split('/')
homedir = '/'
for i in range(1,7):
   homedir = join(homedir, array[i])
homedir
plotPath=homedir+'/plots/'
plotPath
# Out:
# import numpy.random as random
# from astropy import units as u
# import matplotlib.patches as patches
# def: find_nearest(array, value)
# def: powerfunc_six(hpp,amp1,shift1,amp2,shift2,amp3,shift3,amp4,shift4,amp5,shift5,amp6,shift6)
# def: powerfunc_four(hpp,amp1,shift1,amp2,shift2,amp3,shift3,amp4,shift4)
# def: powerfunc(hpp,amp1,shift1,amp2,shift2,amp3,shift3)
# def: powerfuncsingle(hpp,amp1,shift1)
# data_dir :  ~/Documents/GitHub/aroma/AROMA_An_Exo_Rot_Mapping/data
# data_path :  ~/Documents/GitHub/aroma/AROMA_An_Exo_Rot_Mapping/data/processed/luhman_16ab_sector36-37.txt
# plot_dir :  ~/Documents/GitHub/aroma/AROMA_An_Exo_Rot_Mapping/plots
# def: find_nearest(array, value)
# '/Users/nguyendat/Documents/GitHub/aroma/AROMA_An_Exo_Rot_Mapping/plots/'

# %%
data = pd.read_csv(data_path, header=0, delimiter='\t')
time=(data.TIME -data.TIME.iloc[0])*24
lc  =data.PSF_FLUX_NORM
elc =data.PSF_EFLUX

# %%
time
# Out:
# 0          0.000000
# 1          0.166670
# 2          0.333341
# 3          0.500011
# 4          0.666681
#            ...
# 5522    1196.166298
# 5523    1196.332961
# 5524    1196.499624
# 5525    1196.666286
# 5526    1196.832949
# Name: TIME, Length: 5527, dtype: float64

# %%
# Calculate the window Function
wtime = np.linspace(0.,1200,10000)
window = np.zeros(10000)

# Replace data with test sine wave
mu, sigma = 1.0, 0.013 # mean and standard deviation
noise = random.normal(mu, sigma, len(time))
period1 = 5.26
period2 = 6.9
period2 = 4.69
sinelc = 1.0+0.05*np.sin(2*np.pi*(time/period1))+noise
#sinelc = sinelc+0.03*np.sin(2*np.pi*(time/period2))
# plt.plot(sinelc)

# %%
for ii in time:
   #print('Time value:',ii)
   ndx = find_nearest(wtime,ii)
   #print(ndx)
   window[ndx]=1.0

#elc=np.ones(10000)/1000.
#period = 15.
#lc = 0.5*np.sin(2*np.pi*(time/period))

frequen = np.linspace(0.003,10.,100000)

# Compute the GLS periodogram with default options.
# Choose Zechmeister-Kuerster normalization explicitly
clp = pyPeriod.Gls((time,lc,elc), norm="ZK", freq=frequen,ofac=10)

# Calculate the Periodogram for the Window Function
wlp = pyPeriod.Gls((wtime,window), norm="ZK", freq=frequen,ofac=10)
clp.info

sinelp=pyPeriod.Gls((time,sinelc), norm="ZK", freq=frequen,ofac=10)

# %%
plt.figure(), plt.plot(window)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  [<matplotlib.lines.Line2D at 0x7fc4687f6160>])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
fig = plt.figure(figsize=(13,11))
matplotlib.rcParams.update({'font.size': 11})
save = True

fr = clp.freq
pw = clp.power
hpp = 1./fr

wfr = wlp.freq
wpw = wlp.power
whpp = 1./wfr

sinefr = sinelp.freq
sinepw = sinelp.power
sinehpp=1./sinefr

#======================================= [1/5]
## Plot the "Window Function 0-140h"
plt.subplot(4,1,1)
plt.plot(whpp, wpw, '-', linewidth=2.5,color='red')
plt.title('Lomb-Scargle Periodograms of Data, Window Function and Noise-added Sine Wave')

plt.ylim([0.00,0.01])
plt.xlim([0,140])
plt.text(70.0,0.008,'Window Function 0-140h',horizontalalignment='center',fontsize=18)
plt.ylabel('Power')

# plt.plot([2.,2.,19,19],[0.0008,0.001,0.001,0.0008],'-',linewidth=0.5,color='xkcd:red')
# plt.plot([10.5,30],[0.001,0.0018],'-',linewidth=0.5,color='xkcd:red')
# plt.text(10.0,0.002,'Window Function')

#======================================= [2/5]
## Plot the data: Luhman 16 0-140h
plt.subplot(4,1,2)
plt.text(70.0,0.08,'Luhman 16 0-140h',horizontalalignment='center',fontsize=18)

plt.plot(hpp, pw, '-', linewidth=2,color="blue")
plt.ylabel('Power')

# xx=121.
# yy=0.15
# plt.plot([xx,xx],[yy,0.23],color='black',linewidth=0.7)
# plt.text(xx,0.07,'Window function artifact',horizontalalignment='center',fontsize=11)

xx=91.5
yy=0.06
plt.plot([xx,xx],[yy,0.075],color='black',linewidth=0.7)
plt.plot([72,xx],[0.025,0.075],color='black',linewidth=0.7)
plt.text(108,0.08,'Long period without contamination?',horizontalalignment='center',fontsize=11)

xx=63.25
yy=0.02
plt.plot([xx,xx],[yy,0.055],color='black',linewidth=0.7)
plt.text(xx,0.06,'Contaminated real period',horizontalalignment='center',fontsize=11)

xx=6.5
yy=0.02
plt.plot([xx,20],[yy,0.065],color='black',linewidth=0.7)
plt.text(xx,0.07,'Rotational period of Luhman 16B',horizontalalignment='left',fontsize=11)

plt.xlim([0,140])
plt.ylim([0.,0.1])

#======================================= [3/5]
## Plot the: Window Function 0-20h
plt.subplot(4,1,3)
plt.text(10.0,0.004,'Window Function 0-20h',horizontalalignment='center',fontsize=18)
plt.plot(whpp, wpw, '-', linewidth=2,color='red')

plt.ylabel('Power')
plt.xlim([0,20])
plt.ylim([0.,0.005])

#======================================= [4/5]
## Plot the data: Luhman 16 0-20h
plt.subplot(4,1,4)
plt.text(10.0,0.062,'Luhman 16 0-20h',horizontalalignment='center',fontsize=18)
plt.plot(hpp, pw, '-', linewidth=2,color='blue')
plt.ylabel('Power')

xx=121.
yy=0.15
plt.plot([xx,xx],[yy,0.23],color='black',linewidth=0.7)
plt.text(xx,0.25,'Window function artifact',horizontalalignment='center',fontsize=11)

xx=7.1
yy=0.017
plt.plot([xx,xx+1.3],[yy,0.028],color='black',linewidth=0.7)
plt.text(xx+1.3,0.030,"Rotational Period of Luhman 16A",horizontalalignment='left',fontsize=11)

plt.plot([5.4,5.8],[0.045,0.045],color='black',linewidth=0.7)
plt.text(5.85,0.045,'Rotational Period of Luhman 16B',horizontalalignment='left',fontsize=11)

xx=2.46
yy=0.020
plt.plot([xx,xx],[yy,0.03],color='black',linewidth=0.7)
plt.text(xx,0.034,'k=2 wave?',horizontalalignment='center',fontsize=11)

plt.xlim([0,20])
plt.ylim([0,0.08])
plt.xlabel('Time [h]')
# plt.ylabel('Power')

# #======================================= [5/5]
# ## Plot the: LS of a P=5.28 hour sine wave
# plt.subplot(5,1,5)
# plt.text(13.0,0.062,'Noise-added P=5.28 h sine wave',horizontalalignment='center',fontsize=18)
# plt.plot(sinehpp, sinepw, '-', linewidth=2,color='green')
# plt.xlabel('Time [h]')
# plt.ylabel('Power')
# plt.xlim([0,20])
# plt.ylim([0,0.08])

if save:
    plt.savefig(plotPath+'[5x1]periodogram_windowFunction_Data.png', dpi=200)
    plt.savefig(plotPath+'[5x1]periodogram_windowFunction_Data.pdf', dpi=200)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Processing and plotting the periodograms of the window function, X,Y positions, and median pixel distance difference of Luhman 16AB

# %%
# x,y position and source distance to median
xpos = data.X_POSITION
ypos = data.Y_POSITION
dist = np.sqrt((xpos-np.median(xpos))**2 + (ypos-np.median(ypos))**2)
# error
xpos_err = np.repeat(np.std(xpos),len(xpos))
ypos_err = np.repeat(np.std(ypos),len(ypos))

## Calculate periodogram for X,Y position and source pixel-distance variation
# Compute the GLS periodogram with default options.
# Choose Zechmeister-Kuerster normalization explicitly
#clp = pyPeriod.Gls((time,lc,xpos_err), norm="ZK", freq=frequen,ofac=10)
xlp = pyPeriod.Gls((time,xpos,xpos_err), norm="ZK", freq=frequen,ofac=10)
ylp = pyPeriod.Gls((time,ypos,ypos_err), norm="ZK", freq=frequen,ofac=10)
distlp = pyPeriod.Gls((time,dist,np.sqrt(2)*ypos_err), norm="ZK", freq=frequen,ofac=10)

# %%
plt.close()
fig = plt.figure(figsize=(11,11))
matplotlib.rcParams.update({'font.size': 11})
save = True

xfr = xlp.freq
xpw = xlp.power
xhpp = 1./xfr

yfr = ylp.freq
ypw = ylp.power
yhpp = 1./yfr

distfr = distlp.freq
distpw = distlp.power
disthpp = 1./distfr

#======================================= [1]
## Plot the "Window Function"
plt.subplot(5,1,1)
plt.title("Lomb-Scargle Periodograms of the Window Function and the X, Y Positions and Target Distance")
plt.plot(whpp, wpw, '-', linewidth=2.5,color='red')
plt.ylim([0.,0.01])
plt.xlim([0,140])
plt.text(70.0,0.0075,'Window Function',horizontalalignment='center',fontsize=18)
plt.ylabel('Power')
#plt.plot([2.,2.,19,19],[0.0008,0.001,0.001,0.0008],'-',linewidth=0.5,color='xkcd:red')
#plt.plot([10.5,30],[0.001,0.0018],'-',linewidth=0.5,color='xkcd:red')
#plt.text(10.0,0.002,'Window Function')

#======================================= [2]
## Plot the data: Luhman 16
plt.subplot(5,1,2)
plt.text(70.0,0.08,'Luhman 16',horizontalalignment='center',fontsize=18)

plt.plot(hpp, pw, '-', linewidth=2,color="blue")
plt.ylabel('Power')

# xx=121.
# yy=0.15
# plt.plot([xx,xx],[yy,0.23],color='black',linewidth=0.7)
# plt.text(xx,0.07,'Window function artifact',horizontalalignment='center',fontsize=11)

xx=91.5
yy=0.06
plt.plot([xx,xx],[yy,0.075],color='black',linewidth=0.7)
plt.plot([72,xx],[0.025,0.075],color='black',linewidth=0.7)
plt.text(108,0.08,'Long period without contamination?',horizontalalignment='center',fontsize=11)

xx=63.25
yy=0.02
plt.plot([xx,xx],[yy,0.055],color='black',linewidth=0.7)
plt.text(xx,0.06,'Contaminated real period',horizontalalignment='center',fontsize=11)

xx=6.5
yy=0.02
plt.plot([xx,20],[yy,0.065],color='black',linewidth=0.7)
plt.text(xx,0.07,'Rotational period of Luhman 16B',horizontalalignment='left',fontsize=11)

plt.xlim([0,140])
plt.ylim([0.,0.1])

#======================================= [3]
## Plot the: X position 
plt.subplot(5,1,3)
#plt.title("L-S Periodogram of the Luhman 16 TESS Lightcurve")
plt.text(70.0,0.015,'X Position',horizontalalignment='center',fontsize=18)
plt.plot(xhpp, xpw, '-', linewidth=2,color="green")
#plt.xlabel('Time [h]')ß
plt.ylabel('Power')
plt.xlim([0,140])
plt.ylim([0.,0.02])

#======================================= [4]
## Plot the: Y Position
plt.subplot(5,1,4)
#plt.title("L-S Periodogram of the Luhman 16 TESS Lightcurve")
plt.text(70.0,0.015,'Y Position',horizontalalignment='center',fontsize=18)
plt.plot(yhpp, ypw, '-', linewidth=2,color="green")
#plt.xlabel('Time [h]')
plt.ylabel('Power')
plt.xlim([0,140])
plt.ylim([0.,0.02])

#======================================= [5]
## Plot the: Luhman 16 distance
plt.subplot(5,1,5)
plt.text(70.0,0.015,'Distance',horizontalalignment='center',fontsize=18)
plt.plot(disthpp, distpw, '-', linewidth=2,color="purple")
plt.ylabel('Power')
plt.xlim([0,140])
plt.ylim([0.,0.02])
plt.xlabel('Time [h]')
plt.show()

if save:
    plt.savefig(plotPath+'[5x1]XYposDistance_periodogram.png', dpi=200)
    plt.savefig(plotPath+'[5x1]XYposDistance_periodogram.pdf', dpi=200)
# fig.savefig('L16-AD-PositionPeriodogram.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
